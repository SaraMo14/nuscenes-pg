# %%
import pgeon.policy_graph as PG
from pathlib import Path
from example.environment import SelfDrivingEnvironment
from example.discretizer.discretizer import AVDiscretizer
import pandas as pd
from nuscenes import NuScenes
import numpy as np

# %%
city = 'boston-seaport'
env = SelfDrivingEnvironment(city)
disc = AVDiscretizer(env)
    # Generate Policy Graph
    #from existing csv file
    #pg = PG.PolicyGraph.from_nodes_and_edges(str(Path(data_folder) / 'nuscenes_nodes.csv'), str(Path(data_folder) / 'nuscenes_edges.csv'), env, env.discretizer  )

    #from raw data
dtype_dict = {
        'modality': 'category',  # for limited set of modalities, 'category' is efficient
        'scene_token': 'str',  
        'steering_angle': 'float64',  
        'timestamp': 'str',  # To enable datetime operations
        'rotation': 'object',  # Quaternion (lists)
        'x': 'float64',
        'y': 'float64',
        'z': 'float64',
        'yaw': 'float64',  
        'velocity': 'float64',
        'acceleration': 'float64',
        'yaw_rate': 'float64'
        #'is_destination': 'str'
    }

df = pd.read_csv(Path('/home/saramontese/Desktop/MasterThesis/example/dataset/data/sets/nuscenes') / "train_v1.0-mini_lidar_0.csv", dtype=dtype_dict, parse_dates=['timestamp'])
val_df = pd.read_csv(Path('/home/saramontese/Desktop/MasterThesis/example/dataset/data/sets/nuscenes') / "test_v1.0-mini_lidar_0.csv", dtype=dtype_dict, parse_dates=['timestamp'])
df = df[df['location'] == city]
val_df = val_df[val_df['location'] == city]

pg = PG.PolicyGraph(env, disc)

# %%
pg = pg.fit(df, update=False, verbose=False)
# Out:
# Fitting PG from scenes...:   0%|          | 0/4 [00:00<?, ?it/s]
# BlockProgress(INTERSECTION)
# BlockProgress(INTERSECTION)
# BlockProgress(INTERSECTION)
# BlockProgress(INTERSECTION)
# BlockProgress(INTERSECTION)
# BlockProgress(INTERSECTION)
# BlockProgress(INTERSECTION)
# BlockProgress(INTERSECTION)
# BlockProgress(INTERSECTION)
# BlockProgress(INTERSECTION)
# BlockProgress(INTERSECTION)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pg = pg.fit(df, update=False, verbose=False)
#
# File ~/Desktop/MasterThesis/pgeon/policy_graph.py:316, in PolicyGraph.fit(self, scenes, update, verbose)
#     312 rewards = []
#     315 for scene_token, group in scene_groups:
# --> 316     trajectory_result, tot_reward = self._run_episode(group, verbose)
#     317     self._update_with_trajectory(trajectory_result)
#     318     self._trajectories_of_last_fit.append(trajectory_result)
#
# File ~/Desktop/MasterThesis/pgeon/policy_graph.py:244, in PolicyGraph._run_episode(self, scene, verbose)
#     241 reward = (0,0)#self.environment.compute_reward(discretized_last_state, None)
#     242 tot_reward +=sum(reward)
# --> 244 trajectory = self.discretizer.assign_next_intersection(trajectory)
#     245 if verbose:
#     246         print('From', last_state_to_discretize, ' -> END ')
#
# File ~/Desktop/MasterThesis/example/discretizer/discretizer.py:128, in AVDiscretizer.assign_next_intersection(trajectory)
#     126                 state.next_intersection = NextIntersection.LEFT
#     127             else:
# --> 128                 state.next_intersection = NextIntersection.IDLE #TODO: handle idling at an intersection (reasons:traffic light, stop sign, other cars)
#     129             break
#     130 print(trajectory)
#
# AttributeError: 'tuple' object has no attribute 'next_intersection'

# %%
#pg._save_csv('/home/saramontese/Desktop/MasterThesis/example/dataset/data/policy_graphs/pg_nodes.csv', '/home/saramontese/Desktop/MasterThesis/example/dataset/data/policy_graphs/pg_edges.csv','/home/saramontese/Desktop/MasterThesis/example/dataset/data/policy_graphs/pg_traj.csv')

# %% [markdown]
# # TEST AGENTS

# %%
greedy_agent = PG.PGBasedPolicy(pg, mode=PG.PGBasedPolicyMode.GREEDY, node_not_found_mode=PG.PGBasedPolicyNodeNotFoundMode.FIND_SIMILAR_NODES)
stochastic_agent = PG.PGBasedPolicy(pg, mode=PG.PGBasedPolicyMode.STOCHASTIC, node_not_found_mode=PG.PGBasedPolicyNodeNotFoundMode.FIND_SIMILAR_NODES)
random_agent = PG.PGBasedPolicy(pg, mode=PG.PGBasedPolicyMode.STOCHASTIC, node_not_found_mode=PG.PGBasedPolicyNodeNotFoundMode.RANDOM_UNIFORM)

# %%
scene_test = val_df['scene_token'].unique()[43]
example_scene_df = val_df[val_df['scene_token']==scene_test][['x','y','velocity', 'yaw_rate', 'acceleration', 'yaw', 'steering_angle']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 scene_test = val_df['scene_token'].unique()[43]
#       2 example_scene_df = val_df[val_df['scene_token']==scene_test][['x','y','velocity', 'yaw_rate', 'acceleration', 'yaw', 'steering_angle']]
#
# IndexError: index 43 is out of bounds for axis 0 with size 0

# %%
for scene in val_df['scene_token'].unique():
    print(f'SCENE: {scene}')
    example_scene_df = val_df[val_df['scene_token']==scene][['x','y','velocity', 'yaw_rate', 'acceleration', 'yaw', 'steering_angle']]
    stochastic_agent.test_scene_trajectory(example_scene_df, max_steps=20, render=False, verbose = False)

print(f"mean ADE: {np.mean(stochastic_agent.pg_metrics['ADE'])}")
print(f"mean FDE: {np.mean(stochastic_agent.pg_metrics['FDE'])}")

# %%
stochastic_agent.test_scene_trajectory(example_scene_df, max_steps=20, render=True, verbose = True)
#diff_aer, diff_std, transferred_learning = stochastic_agent.compare()
# Out:
# ---------------------------------
# * START TESTING
#
# Actual state: [1101.6246655482323, 1194.960742062142, 8.066120189697818, -0.0149526060529721, 0.260762064933797, 2.5378086432271503, -0.0959211333477157]
# Action: Action.BRAKE
# Actual state: (1098.3046783136704, 1197.2505583191828, 8.065620189697817, -0.0149526060529721, -0.001, 2.530332340200664, 0.0)
# Action: Action.BRAKE
# Actual state: (1095.0021077962724, 1199.5649881061343, 8.065120189697817, -0.0149526060529721, -0.001, 2.522856037174178, 0.0)
# Action: Action.STRAIGHT
# Actual state: (1091.7171364474054, 1201.90389899706, 8.065120189697817, -0.0149526060529721, 0, 2.515379734147692, 0.0)
# Action: Action.BRAKE
# Actual state: (1088.4497431486955, 1204.2673037338989, 8.064620189697816, -0.0149526060529721, -0.001, 2.5079034311212056, 0.0)
# Action: Action.BRAKE
# Actual state: (1085.2003119927217, 1206.6549221840721, 8.064120189697816, -0.0149526060529721, -0.001, 2.5004271280947195, 0.0)
# Action: Action.BRAKE
# Actual state: (1081.9690223925202, 1209.0666178796569, 8.063620189697815, -0.0149526060529721, -0.001, 2.4929508250682333, 0.0)
# Action: Action.STRAIGHT
# Actual state: (1078.7560527246478, 1211.5022530235685, 8.063620189697815, -0.0149526060529721, 0, 2.485474522041747, 0.0)
# Action: Action.BRAKE
# Actual state: (1075.5613822277596, 1213.961841008829, 8.063120189697814, -0.0149526060529721, -0.001, 2.477998219015261, 0.0)
# Action: Action.BRAKE
# Actual state: (1072.385386413304, 1216.4450903690301, 8.062620189697814, -0.0149526060529721, -0.001, 2.470521915988775, 0.0)
# Action: Action.STRAIGHT
# Actual state: (1069.228240500578, 1218.951859358504, 8.062620189697814, -0.0149526060529721, 0, 2.4630456129622886, 0.0)
# Action: Action.BRAKE
# Actual state: (1066.0899240119365, 1221.4821618498975, 8.062120189697813, -0.0149526060529721, -0.001, 2.4555693099358025, 0.0)
# Action: Action.GAS
# Actual state: (1062.9708058058984, 1224.0356980460467, 8.062620189697814, -0.0149526060529721, 0.001, 2.4480930069093163, 0.0)
# Action: Action.BRAKE
# Actual state: (1059.8706733503097, 1226.6126419411744, 8.062120189697813, -0.0149526060529721, -0.001, 2.44061670388283, 0.0)
# Action: Action.GAS
# Actual state: (1056.7900844226733, 1229.2125298901458, 8.062620189697814, -0.0149526060529721, 0.001, 2.433140400856344, 0.0)
# Action: Action.BRAKE
# Actual state: (1053.7288291161638, 1231.835539045524, 8.062120189697813, -0.0149526060529721, -0.001, 2.425664097829858, 0.0)
# Action: Action.BRAKE
# Actual state: (1050.6874582134865, 1234.4811974740878, 8.061620189697813, -0.0149526060529721, -0.001, 2.4181877948033716, 0.0)
# Action: Action.GAS
# Actual state: (1047.666139258207, 1237.1493544768155, 8.062120189697813, -0.0149526060529721, 0.001, 2.4107114917768855, 0.0)
# Action: Action.GAS
# Actual state: (1043.1046966177803, 1237.483358120463, 0, 0, 0, 2.4032351887503993, 0.0)
# Action: Action.GAS
# Actual state: (1043.1046966177803, 1237.483358120463, 0, 0, 0, 2.4032351887503993, 0.0)
# Action: Action.GAS
# ADE: 3.9092150358262403 and FDE: 6.738280403409906 --> Episode Mean Time: 1.0703842639923096
# * END TESTING
# ---------------------------------
# * RESULTS
# * PG agent path
# Creating plot...
# /home/saramontese/.local/lib/python3.8/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
# /home/saramontese/.local/lib/python3.8/site-packages/descartes/patch.py:64: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   [asarray(r)[:, :2] for r in t.interiors])
# * True agent path
#                 x            y  velocity  yaw_rate  acceleration       yaw  \
# 6274  1101.624666  1194.960742  8.066120 -0.014953      0.260762  2.537809
# 6275  1098.385443  1197.246994  7.930979 -0.022568     -0.270331  2.526527
# 6276  1095.167132  1199.579104  7.960285 -0.021746      0.058697  2.515669
# 6277  1092.048681  1201.905684  7.791711 -0.024725     -0.337593  2.503323
# 6278  1088.931846  1204.276975  7.834896 -0.021913      0.086393  2.492369
# 6279  1085.799997  1206.701031  7.922165  0.001391      0.174571  2.493065
# 6280  1082.734854  1209.021713  7.699921  0.025988     -0.445112  2.506041
# 6281  1080.038010  1211.003114  7.444046  0.032053     -0.569181  2.520450
# 6282  1077.074189  1213.140034  7.317562  0.025487     -0.253308  2.533177
# 6283  1074.150789  1215.178779  7.129938  0.017617     -0.375340  2.541983
# 6284  1071.149814  1217.248449  6.619047  0.010861     -0.927624  2.547964
# 6285  1068.549668  1219.013743  6.273351  0.007739     -0.690050  2.551842
# 6286  1066.113756  1220.681789  5.899564 -0.018186     -0.746937  2.542741
# 6287  1063.875948  1222.250612  5.461216 -0.030983     -0.875947  2.527236
# 6288  1061.754533  1223.802192  5.251677 -0.035997     -0.418691  2.509221
# 6289  1059.605416  1225.411007  5.364800 -0.033608      0.226063  2.492403
# 6290  1057.389864  1227.150166  5.634647 -0.027364      0.539828  2.478725
# 6291  1054.730653  1229.259776  6.790579  0.007008      2.312479  2.482228
# 6292  1051.851893  1231.490304  7.285355  0.030077      0.989798  2.497263
# 6293  1048.753626  1233.809938  7.742446  0.042251      0.914378  2.518384
#
#       steering_angle
# 6274       -0.095921
# 6275       -0.102902
# 6276       -0.101157
# 6277       -0.090685
# 6278       -0.040071
# 6279        0.087338
# 6280        0.183332
# 6281        0.181586
# 6282        0.139698
# 6283        0.108282
# 6284        0.071630
# 6285       -0.059269
# 6286       -0.170970
# 6287       -0.270454
# 6288       -0.263473
# 6289       -0.174461
# 6290       -0.031344
# 6291        0.146680
# 6292        0.240927
# 6293        0.225219
# Creating plot...
# /home/saramontese/.local/lib/python3.8/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
# /home/saramontese/.local/lib/python3.8/site-packages/descartes/patch.py:64: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   [asarray(r)[:, :2] for r in t.interiors])
# Error in callback <function flush_figures at 0x7fc62f505ee0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~/.local/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File ~/.local/lib/python3.8/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/backend_bases.py:2299, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2297 if bbox_inches:
#    2298     if bbox_inches == "tight":
# -> 2299         bbox_inches = self.figure.get_tightbbox(
#    2300             renderer, bbox_extra_artists=bbox_extra_artists)
#    2301         if pad_inches is None:
#    2302             pad_inches = rcParams['savefig.pad_inches']
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/figure.py:1684, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1681     artists = bbox_extra_artists
#    1683 for a in artists:
# -> 1684     bbox = a.get_tightbbox(renderer)
#    1685     if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    1686         bb.append(bbox)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/artist.py:356, in Artist.get_tightbbox(self, renderer)
#     341 def get_tightbbox(self, renderer):
#     342     """
#     343     Like `.Artist.get_window_extent`, but includes any clipping.
#     344
#    (...)
#     354         The enclosing bounding box (in figure pixel coordinates).
#     355     """
# --> 356     bbox = self.get_window_extent(renderer)
#     357     if self.get_clip_on():
#     358         clip_box = self.get_clip_box()
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/patches.py:629, in Patch.get_window_extent(self, renderer)
#     628 def get_window_extent(self, renderer=None):
# --> 629     return self.get_path().get_extents(self.get_transform())
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/path.py:614, in Path.get_extents(self, transform, **kwargs)
#     612 from .transforms import Bbox
#     613 if transform is not None:
# --> 614     self = transform.transform_path(self)
#     615 if self.codes is None:
#     616     xys = self.vertices
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/transforms.py:1608, in Transform.transform_path(self, path)
#    1601 def transform_path(self, path):
#    1602     """
#    1603     Apply the transform to `.Path` *path*, returning a new `.Path`.
#    1604
#    1605     In some cases, this transform may insert curves into the path
#    1606     that began as line segments.
#    1607     """
# -> 1608     return self.transform_path_affine(self.transform_path_non_affine(path))
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/transforms.py:1618, in Transform.transform_path_affine(self, path)
#    1610 def transform_path_affine(self, path):
#    1611     """
#    1612     Apply the affine part of this transform to `.Path` *path*, returning a
#    1613     new `.Path`.
#    (...)
#    1616     ``transform_path_affine(transform_path_non_affine(values))``.
#    1617     """
# -> 1618     return self.get_affine().transform_path_affine(path)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/transforms.py:1815, in AffineBase.transform_path_affine(self, path)
#    1813 def transform_path_affine(self, path):
#    1814     # docstring inherited
# -> 1815     return Path(self.transform_affine(path.vertices),
#    1816                 path.codes, path._interpolation_steps)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/path.py:130, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     101 """
#     102 Create a new path with the given vertices and codes.
#     103
#    (...)
#     127     and codes as read-only arrays.
#     128 """
#     129 vertices = _to_unmasked_float_array(vertices)
# --> 130 _api.check_shape((None, 2), vertices=vertices)
#     132 if codes is not None:
#     133     codes = np.asarray(codes, self.code_type)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/_api/__init__.py:154, in check_shape(_shape, **kwargs)
#     149 for k, v in kwargs.items():
#     150     data_shape = v.shape
#     152     if len(target_shape) != len(data_shape) or any(
#     153             t not in [s, None]
# --> 154             for t, s in zip(target_shape, data_shape)
#     155     ):
#     156         dim_labels = iter(itertools.chain(
#     157             'MNLIJKLH',
#     158             (f"D{i}" for i in itertools.count())))
#     159         text_shape = ", ".join((str(n)
#     160                                 if n is not None
#     161                                 else next(dim_labels)
#     162                                 for n in target_shape))
#
# KeyboardInterrupt:

# %%
for scene in val_df['scene_token'].unique():
    print(f'SCENE: {scene}')
    example_scene_df = val_df[val_df['scene_token']==scene][['x','y','velocity', 'yaw_rate', 'acceleration', 'yaw', 'steering_angle']]
    greedy_agent.test_scene_trajectory(example_scene_df, max_steps=20, render=False, verbose = False)

print(f"mean ADE: {np.mean(greedy_agent.pg_metrics['ADE'])}")
print(f"mean FDE: {np.mean(greedy_agent.pg_metrics['FDE'])}")
# Out:
# SCENE: 010fb5bcc7984d0f8f07f99e02366df1
# ---------------------------------
# * START TESTING
#
# ADE: 3.9384507519009526 and FDE: 12.841699535463187 --> Episode Mean Time: 0.9437777996063232
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 098c11f50ff2425a9ff994e004de1216
# ---------------------------------
# * START TESTING
#
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# ADE: 27.102158746500216 and FDE: 48.344892764714785 --> Episode Mean Time: 0.6556422710418701
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 0ac05652a4c44374998be876ba5cd6fd
# ---------------------------------
# * START TESTING
#
# No nearest states available.
# ADE: 28.455201895817616 and FDE: 57.63315275247122 --> Episode Mean Time: 1.4665305614471436
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 13c6a31ab85547b08dab2544024553a8
# ---------------------------------
# * START TESTING
#
# No nearest states available.
# ADE: 5.593960392411029 and FDE: 22.46662583319287 --> Episode Mean Time: 1.5221281051635742
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 1959c8f440a340fda3ea2cac0ac528ec
# ---------------------------------
# * START TESTING
#
# ADE: 0.01247625045485728 and FDE: 0.016425179774424536 --> Episode Mean Time: 1.449760913848877
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 19f47b8941094af29b8db20b255717fc
# ---------------------------------
# * START TESTING
#
# ADE: 0.00014889244659312858 and FDE: 0.00021283507836112795 --> Episode Mean Time: 1.1902847290039062
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 1b3b150c9d3e4e1593e7ce882a69f870
# ---------------------------------
# * START TESTING
#
# ADE: 2.8013563438373716 and FDE: 11.685879360336623 --> Episode Mean Time: 1.0519235134124756
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 1d25e9071ea94891b5eb7554e77a11bb
# ---------------------------------
# * START TESTING
#
# ADE: 16.38042981283412 and FDE: 41.92915863938291 --> Episode Mean Time: 0.6185567378997803
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 1e3f0bd8063a4084b7104345b20bfb80
# ---------------------------------
# * START TESTING
#
# ADE: 10.659029506963595 and FDE: 26.446670897622433 --> Episode Mean Time: 0.8352816104888916
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 1ec0b9bc3eca4b76b2610c519f843762
# ---------------------------------
# * START TESTING
#
# ADE: 3.2996732666302018 and FDE: 5.828591755726957 --> Episode Mean Time: 0.4475531578063965
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 210add02013a4dfa84b7c5e23058781f
# ---------------------------------
# * START TESTING
#
# ADE: 3.9906762916462397 and FDE: 13.882997114981244 --> Episode Mean Time: 1.2596521377563477
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 23663ff8f4614b8bb005d67e51a69283
# ---------------------------------
# * START TESTING
#
# ADE: 0.01790365070469162 and FDE: 0.049899223888444144 --> Episode Mean Time: 0.9429426193237305
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 2575c1870ede486b8568279b4731e47e
# ---------------------------------
# * START TESTING
#
# ADE: 4.196562173471922 and FDE: 9.523603985218774 --> Episode Mean Time: 1.3620524406433105
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 2abb3f3517c64446a5768df5665da49d
# ---------------------------------
# * START TESTING
#
# ADE: 7.871411179455419 and FDE: 23.16263563469731 --> Episode Mean Time: 0.5449364185333252
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 2ed0fcbfc214478ca3b3ce013e7723ba
# ---------------------------------
# * START TESTING
#
# ADE: 3.6041067168856467 and FDE: 3.7145888870212134 --> Episode Mean Time: 1.3965086936950684
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 30e77a3561ce4f1bb4fd90e322ea29d7
# ---------------------------------
# * START TESTING
#
# ADE: 1.2721329292007977 and FDE: 5.808193175369286 --> Episode Mean Time: 1.4551665782928467
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 37a37b06ba5e4f978fc6cb77e90f2498
# ---------------------------------
# * START TESTING
#
# ADE: 15.98585298101039 and FDE: 41.02620981844241 --> Episode Mean Time: 0.7492649555206299
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 3b2ee26cb8484f77895bc336663df502
# ---------------------------------
# * START TESTING
#
# ADE: 20.17235258465939 and FDE: 56.52860803717243 --> Episode Mean Time: 0.7483432292938232
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 3d42cd90a8184d9ebd3bb85b6416314d
# ---------------------------------
# * START TESTING
#
# ADE: 1.318593041770575e-06 and FDE: 7.677395437429035e-07 --> Episode Mean Time: 0.6374490261077881
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 3e1f0257a4b8457486651de2d16b61ab
# ---------------------------------
# * START TESTING
#
# ADE: 0.000105221334617656 and FDE: 0.00014971447652342706 --> Episode Mean Time: 0.7308447360992432
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 3f90afe9f7dc49399347ae1626502aed
# ---------------------------------
# * START TESTING
#
# No nearest states available.
# ADE: 18.602910684856983 and FDE: 38.18453996288343 --> Episode Mean Time: 1.0701229572296143
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 453453c849304ad69741891946d46453
# ---------------------------------
# * START TESTING
#
# ADE: 0.005542313877918337 and FDE: 0.0077793662490769095 --> Episode Mean Time: 0.9053022861480713
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 491322eec05043c9907c59aa35b046ea
# ---------------------------------
# * START TESTING
#
# ADE: 14.999980834302542 and FDE: 36.582607101455395 --> Episode Mean Time: 1.8540422916412354
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 4bcb814456f044919bc052c208dbebc5
# ---------------------------------
# * START TESTING
#
# ADE: 8.997345303858044 and FDE: 39.768394243882604 --> Episode Mean Time: 0.6584506034851074
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 52bb785dcb5548a1836898f14fb3cf6d
# ---------------------------------
# * START TESTING
#
# ADE: 0.0007629883976716799 and FDE: 0.001090454150637743 --> Episode Mean Time: 1.256199836730957
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 52fa2df7fde34bd58ee30cff02b73f51
# ---------------------------------
# * START TESTING
#
# ADE: 8.046461330428218e-05 and FDE: 0.00012203440742186325 --> Episode Mean Time: 0.4530460834503174
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 579fb61492be4ffc97132658f8e4bb9c
# ---------------------------------
# * START TESTING
#
# ADE: 4.503499710967785e-05 and FDE: 6.270821984355471e-05 --> Episode Mean Time: 0.3342173099517822
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 57dc3221a3d845b5ab17ff0f98ce336f
# ---------------------------------
# * START TESTING
#
# ADE: 9.510476842233672e-05 and FDE: 0.00013706031922873486 --> Episode Mean Time: 0.7446761131286621
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 59530445fcc04c2090bfaf63f342f794
# ---------------------------------
# * START TESTING
#
# ADE: 17.383300746167883 and FDE: 43.5984569786921 --> Episode Mean Time: 0.8916616439819336
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 5a1d2867bb504c888a628ad549cc10b6
# ---------------------------------
# * START TESTING
#
# ADE: 22.518992128107143 and FDE: 54.28938617927698 --> Episode Mean Time: 1.3333444595336914
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 5e30d846d2344ec2addfb664799d1899
# ---------------------------------
# * START TESTING
#
# ADE: 37.442455725429234 and FDE: 76.85810074378419 --> Episode Mean Time: 0.8205640316009521
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 60111bb5388f4195b98555d4d4b89618
# ---------------------------------
# * START TESTING
#
# ADE: 2.3174586964148514 and FDE: 3.9371958804338414 --> Episode Mean Time: 1.2052490711212158
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 6447a9c30b0140d783871b08104ae7b3
# ---------------------------------
# * START TESTING
#
# ADE: 0.5703168036244769 and FDE: 0.5075807406109729 --> Episode Mean Time: 0.7631285190582275
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 64a3a2d22172406c848f2a92275808ba
# ---------------------------------
# * START TESTING
#
# ADE: 25.13849972532113 and FDE: 57.701334060747094 --> Episode Mean Time: 1.2827441692352295
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 66e050dbde3447e5a4b07f0d896f5864
# ---------------------------------
# * START TESTING
#
# ADE: 24.890376219112042 and FDE: 45.140075552289936 --> Episode Mean Time: 1.3751237392425537
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 6946bd49ebe648b7a8c4555774059bc8
# ---------------------------------
# * START TESTING
#
# ADE: 1.3159581352327527 and FDE: 5.058922718811063 --> Episode Mean Time: 0.673839807510376
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 69e393da7cb54eb6bea7927a2af0d1ee
# ---------------------------------
# * START TESTING
#
# ADE: 0.21159557872308138 and FDE: 2.5189446277282888 --> Episode Mean Time: 0.37024664878845215
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 6a24a80e2ea3493c81f5fdb9fe78c28a
# ---------------------------------
# * START TESTING
#
# ADE: 1.4718416697695043 and FDE: 5.4793689433314325 --> Episode Mean Time: 1.1738572120666504
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 6d6314f1865343f987ca53107b694745
# ---------------------------------
# * START TESTING
#
# No nearest states available.
# ADE: 10.164929843459229 and FDE: 19.218857996371074 --> Episode Mean Time: 0.6785843372344971
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 7ad327c8827849ed91136bb2d04acec9
# ---------------------------------
# * START TESTING
#
# ADE: 0.021935640847935305 and FDE: 0.030724903118309048 --> Episode Mean Time: 0.9431724548339844
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 7ad94b6e54f641208bf59cba6bb55220
# ---------------------------------
# * START TESTING
#
# ADE: 24.29595382519326 and FDE: 55.81581764102599 --> Episode Mean Time: 1.1509454250335693
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 7ca5e90766dc4b7bb6a9b3b0d95c99da
# ---------------------------------
# * START TESTING
#
# ADE: 3.6390648058528496 and FDE: 9.156139345372615 --> Episode Mean Time: 0.6998612880706787
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 7e8ff24069ff4023ac699669b2c920de
# ---------------------------------
# * START TESTING
#
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# ADE: 41.82110713748938 and FDE: 81.2744262535603 --> Episode Mean Time: 0.622901201248169
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 827712f3e79340d8878de0202c5b3960
# ---------------------------------
# * START TESTING
#
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# ADE: 19.433386505955387 and FDE: 44.69097118721735 --> Episode Mean Time: 1.4095814228057861
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 84f4c0747550493f959595dae6785cd3
# ---------------------------------
# * START TESTING
#
# ADE: 7.868390753224846 and FDE: 24.011874647816636 --> Episode Mean Time: 0.9821982383728027
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 862a468e56954dc9a833a9eb3ebd884b
# ---------------------------------
# * START TESTING
#
# ADE: 4.916178271562527 and FDE: 8.354991346133069 --> Episode Mean Time: 1.1925158500671387
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 875e9b8b63b54263ba1edeb21faadea8
# ---------------------------------
# * START TESTING
#
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# ADE: 15.884921582068012 and FDE: 47.77913055698464 --> Episode Mean Time: 0.9119699001312256
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 9068766ee9374872a380fe75fcfb299e
# ---------------------------------
# * START TESTING
#
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# ADE: 20.658971690314882 and FDE: 34.56623770882032 --> Episode Mean Time: 0.9425194263458252
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 91c071bcc1ad4fa1b555399e1cfbab79
# ---------------------------------
# * START TESTING
#
# ADE: 6.825792708548654 and FDE: 17.01863063588402 --> Episode Mean Time: 1.3331358432769775
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: 9a442b0f6b7a41568b3e4f7b7ba58402
# ---------------------------------
# * START TESTING
#
# ADE: 43.256630813292716 and FDE: 92.41403891740485 --> Episode Mean Time: 0.920496940612793
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: a2b005c4dd654af48194ada18662c8ca
# ---------------------------------
# * START TESTING
#
# ADE: 3.081182589589896 and FDE: 3.8085462395604255 --> Episode Mean Time: 1.4896409511566162
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: a59b6db922ff490da5ccfc9980700935
# ---------------------------------
# * START TESTING
#
# ADE: 0.187432001003265 and FDE: 0.19094260758695564 --> Episode Mean Time: 0.9792389869689941
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: a6fae4900f8e46cba689b59b5bc8a2ab
# ---------------------------------
# * START TESTING
#
# ADE: 2.1257066462850736 and FDE: 5.30089491232224 --> Episode Mean Time: 1.2612791061401367
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: a8819942e8bb43b6a832c56dfb78cfc6
# ---------------------------------
# * START TESTING
#
# ADE: 1.9744900118456516 and FDE: 8.402471192225828 --> Episode Mean Time: 1.0818984508514404
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: a8bd4c1efe284a5bba46f59454764965
# ---------------------------------
# * START TESTING
#
# ADE: 11.578660407122205 and FDE: 34.869585818897235 --> Episode Mean Time: 0.9484517574310303
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: aa54277d163d419b9f952b014112643e
# ---------------------------------
# * START TESTING
#
# ADE: 0.0018051681844668175 and FDE: 0.002577124830415497 --> Episode Mean Time: 0.28707361221313477
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: b07358651c604e2d83da7c4d4755de73
# ---------------------------------
# * START TESTING
#
# ADE: 8.03763830207688 and FDE: 19.27443479608388 --> Episode Mean Time: 1.3809475898742676
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: b789de07180846cc972118ee6d1fb027
# ---------------------------------
# * START TESTING
#
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# ADE: 21.515471295820358 and FDE: 41.3835552017036 --> Episode Mean Time: 0.8143653869628906
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: b94fbf78579f4ff5ab5dbd897d5e3199
# ---------------------------------
# * START TESTING
#
# ADE: 10.373392127436613 and FDE: 27.71996095248916 --> Episode Mean Time: 1.2404117584228516
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: c133e78e55ae487c821803a3b183d1ab
# ---------------------------------
# * START TESTING
#
# ADE: 9.328910541141349 and FDE: 29.62563260969748 --> Episode Mean Time: 0.9434471130371094
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: c164a8e8e8b8489f964f711f472789be
# ---------------------------------
# * START TESTING
#
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# ADE: 24.37119810840138 and FDE: 52.866940650006775 --> Episode Mean Time: 1.159693956375122
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: c468cdcc838143d480b5b9c835c8380c
# ---------------------------------
# * START TESTING
#
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# ADE: 0.03697083639701549 and FDE: 0.04406178130202134 --> Episode Mean Time: 0.702662467956543
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: c4ab236557c8423caa8add5fb48a0898
# ---------------------------------
# * START TESTING
#
# ADE: 1.7411666273890034 and FDE: 9.918794465055399 --> Episode Mean Time: 1.1862356662750244
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: c5b36e5275cc4a2285d095e87347c49a
# ---------------------------------
# * START TESTING
#
# ADE: 9.789809979905815 and FDE: 27.653395740308603 --> Episode Mean Time: 1.274071455001831
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: cb0cd06a1dd84271968466d7b65e48f8
# ---------------------------------
# * START TESTING
#
# ADE: 17.13583683035546 and FDE: 43.39298453053587 --> Episode Mean Time: 1.0949299335479736
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: cf3db17f34cd412faca3535ac8c7069a
# ---------------------------------
# * START TESTING
#
# ADE: 2.057465124552372 and FDE: 1.107182430825974 --> Episode Mean Time: 0.9447355270385742
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: d58468c6097c425e89671a7b3f480acf
# ---------------------------------
# * START TESTING
#
# ADE: 19.431384485994577 and FDE: 49.252712407040754 --> Episode Mean Time: 0.9362969398498535
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: d654cae175de44319ace178994ed0329
# ---------------------------------
# * START TESTING
#
# ADE: 1.9481354396185195 and FDE: 8.745116993856625 --> Episode Mean Time: 0.9747610092163086
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: d8a5dd6087de4e808c61c27f91e8216e
# ---------------------------------
# * START TESTING
#
# ADE: 3.217437197001513 and FDE: 3.923521844367691 --> Episode Mean Time: 1.215397834777832
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: dbd9183e1278475ea54761297e004b04
# ---------------------------------
# * START TESTING
#
# ADE: 0.46598019917315214 and FDE: 0.5765075301954721 --> Episode Mean Time: 1.1221163272857666
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: dc9ef63b61394d3d8effeb51919f2144
# ---------------------------------
# * START TESTING
#
# No nearest states available.
# ADE: 7.602168836825068 and FDE: 17.64235662921632 --> Episode Mean Time: 1.6733436584472656
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: ddb615d9bb22484cabc6545b632a1025
# ---------------------------------
# * START TESTING
#
# ADE: 16.408626525117214 and FDE: 41.248279165920756 --> Episode Mean Time: 0.8291950225830078
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: deab903b0b644d7a984c552968026631
# ---------------------------------
# * START TESTING
#
# ADE: 32.513536283441624 and FDE: 67.88075709875612 --> Episode Mean Time: 1.4518396854400635
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: e083627747d8499a8c4e94c7abf941e2
# ---------------------------------
# * START TESTING
#
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# ADE: 29.74023251389699 and FDE: 63.42837316215168 --> Episode Mean Time: 0.8097536563873291
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: e3094e1174654d119b55cce4df145e02
# ---------------------------------
# * START TESTING
#
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# ADE: 36.38101967275018 and FDE: 73.10075807820647 --> Episode Mean Time: 1.2598216533660889
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: e329b73341204af7a9de29e65291ce1c
# ---------------------------------
# * START TESTING
#
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# No nearest states available.
# ADE: 26.50616780175698 and FDE: 54.62151852036568 --> Episode Mean Time: 1.3717284202575684
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: ed97ee6a3b444ba7800641baab057556
# ---------------------------------
# * START TESTING
#
# ADE: 8.557301308114836 and FDE: 37.39453432896339 --> Episode Mean Time: 0.7657263278961182
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: ee909cb746e44174be804f26bc971efe
# ---------------------------------
# * START TESTING
#
# ADE: 7.124673367310059 and FDE: 25.00821998026134 --> Episode Mean Time: 0.8394656181335449
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: efe3681f556b43e6aa65bf7bfc61a2f8
# ---------------------------------
# * START TESTING
#
# ADE: 5.475366298624779 and FDE: 15.519046976990884 --> Episode Mean Time: 0.8621809482574463
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: f12b4e7fb95646ec9dac305076024bb9
# ---------------------------------
# * START TESTING
#
# ADE: 0.43499677798027186 and FDE: 0.2768992100048896 --> Episode Mean Time: 0.8520188331604004
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: f55c8c62235146d895f611176fd0a5dc
# ---------------------------------
# * START TESTING
#
# ADE: 3.8541567514417177e-05 and FDE: 5.492677681957092e-05 --> Episode Mean Time: 0.6901907920837402
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: f5b29a1e09d04355adcd60ab72de006b
# ---------------------------------
# * START TESTING
#
# ADE: 13.636797285288694 and FDE: 29.892588345254545 --> Episode Mean Time: 0.3701748847961426
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: fcbccedd61424f1b85dcbf8f897f9754
# ---------------------------------
# * START TESTING
#
# ADE: 22.494246041675147 and FDE: 40.7061746856653 --> Episode Mean Time: 0.15676116943359375
# * END TESTING
# ---------------------------------
# * RESULTS
# SCENE: fe3aa64e4339456186c38c6308f5fb1a
# ---------------------------------
# * START TESTING
#
# ADE: 3.9099924862027633 and FDE: 6.738280403409906 --> Episode Mean Time: 1.0366096496582031
# * END TESTING
# ---------------------------------
# * RESULTS
# mean ADE: 9.089209940878794
# mean FDE: 22.147668669503872

# %%
greedy_agent.test_scene_trajectory(example_scene_df, max_steps=20, render=True, verbose = True)
#diff_aer, diff_std, transferred_learning = greedy_agent.compare()
# Out:
# ---------------------------------
# * START TESTING
#
# Actual state: [1101.6246655482323, 1194.960742062142, 8.066120189697818, -0.0149526060529721, 0.260762064933797, 2.5378086432271503, -0.0959211333477157]
# Action: Action.BRAKE
# Actual state: (1098.3046783136704, 1197.2505583191828, 8.065620189697817, -0.0149526060529721, -0.001, 2.530332340200664, 0.0)
# Action: Action.STRAIGHT
# Actual state: (1095.0021077962724, 1199.5649881061343, 8.065620189697817, -0.0149526060529721, 0, 2.522856037174178, 0.0)
# Action: Action.STRAIGHT
# Actual state: (1091.7169327944362, 1201.904043998674, 8.065620189697817, -0.0149526060529721, 0, 2.515379734147692, 0.0)
# Action: Action.BRAKE
# Actual state: (1088.4493369325144, 1204.267595255632, 8.065120189697817, -0.0149526060529721, -0.001, 2.5079034311212056, 0.0)
# Action: Action.BRAKE
# Actual state: (1085.1997043144086, 1206.655361736239, 8.064620189697816, -0.0149526060529721, -0.001, 2.5004271280947195, 0.0)
# Action: Action.BRAKE
# Actual state: (1081.9682143644152, 1209.0672069642983, 8.064120189697816, -0.0149526060529721, -0.001, 2.4929508250682333, 0.0)
# Action: Action.BRAKE
# Actual state: (1078.75504547029, 1211.5029931343674, 8.063620189697815, -0.0149526060529721, -0.001, 2.485474522041747, 0.0)
# Action: Action.BRAKE
# Actual state: (1075.5603749734018, 1213.9625811196279, 8.063120189697814, -0.0149526060529721, -0.001, 2.477998219015261, 0.0)
# Action: Action.BRAKE
# Actual state: (1072.3843791589463, 1216.445830479829, 8.062620189697814, -0.0149526060529721, -0.001, 2.470521915988775, 0.0)
# Action: Action.STRAIGHT
# Actual state: (1069.2272332462203, 1218.9525994693029, 8.062620189697814, -0.0149526060529721, 0, 2.4630456129622886, 0.0)
# Action: Action.BRAKE
# Actual state: (1066.0889167575788, 1221.4829019606964, 8.062120189697813, -0.0149526060529721, -0.001, 2.4555693099358025, 0.0)
# Action: Action.GAS
# Actual state: (1062.9697985515406, 1224.0364381568456, 8.062620189697814, -0.0149526060529721, 0.001, 2.4480930069093163, 0.0)
# Action: Action.BRAKE
# Actual state: (1059.869666095952, 1226.6133820519733, 8.062120189697813, -0.0149526060529721, -0.001, 2.44061670388283, 0.0)
# Action: Action.GAS
# Actual state: (1056.7890771683155, 1229.2132700009447, 8.062620189697814, -0.0149526060529721, 0.001, 2.433140400856344, 0.0)
# Action: Action.BRAKE
# Actual state: (1053.727821861806, 1231.836279156323, 8.062120189697813, -0.0149526060529721, -0.001, 2.425664097829858, 0.0)
# Action: Action.BRAKE
# Actual state: (1050.6864509591287, 1234.4819375848867, 8.061620189697813, -0.0149526060529721, -0.001, 2.4181877948033716, 0.0)
# Action: Action.GAS
# Actual state: (1047.6651320038493, 1237.1500945876144, 8.062120189697813, -0.0149526060529721, 0.001, 2.4107114917768855, 0.0)
# Action: Action.GAS
# Actual state: (1043.1046966177803, 1237.483358120463, 0, 0, 0, 2.4032351887503993, 0.0)
# Action: Action.GAS
# Actual state: (1043.1046966177803, 1237.483358120463, 0, 0, 0, 2.4032351887503993, 0.0)
# Action: Action.GAS
# ADE: 3.9099924862027633 and FDE: 6.738280403409906 --> Episode Mean Time: 1.0823025703430176
# * END TESTING
# ---------------------------------
# * RESULTS
# * PG agent path
# Creating plot...
# /home/saramontese/.local/lib/python3.8/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
# /home/saramontese/.local/lib/python3.8/site-packages/descartes/patch.py:64: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   [asarray(r)[:, :2] for r in t.interiors])
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1888: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1925: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if layer_name is 'traffic_light':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1971: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1986: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:2006: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if layer_name is 'traffic_light':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1888: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1925: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if layer_name is 'traffic_light':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1971: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1986: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:2006: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if layer_name is 'traffic_light':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1888: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1925: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if layer_name is 'traffic_light':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1971: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1986: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:2006: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if layer_name is 'traffic_light':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1888: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1925: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if layer_name is 'traffic_light':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1971: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1986: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:2006: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if layer_name is 'traffic_light':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1888: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1925: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if layer_name is 'traffic_light':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1971: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1986: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:2006: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if layer_name is 'traffic_light':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1888: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1925: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if layer_name is 'traffic_light':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1971: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1986: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:2006: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if layer_name is 'traffic_light':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1888: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1925: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if layer_name is 'traffic_light':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1971: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1986: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if new_polygon.geom_type is 'Polygon':
# /home/saramontese/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:2006: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if layer_name is 'traffic_light':
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 greedy_agent.test_scene_trajectory(example_scene_df, max_steps=20, render=True, verbose = True)
#       2 #diff_aer, diff_std, transferred_learning = greedy_agent.compare()
#
# File ~/Desktop/MasterThesis/pgeon/policy_graph.py:1292, in PGBasedPolicy.test_scene_trajectory(self, ground_truth_traj, max_steps, verbose, render)
#    1289 if render:
#    1290     #render PG agent path
#    1291     print('* PG agent path')
# -> 1292     self.pg.environment.render_egoposes_on_fancy_map(pred_trajectory)
#    1294     #render true path
#    1295     print('* True agent path')
#
# File ~/Desktop/MasterThesis/example/environment.py:161, in SelfDrivingEnvironment.render_egoposes_on_fancy_map(self, map_poses, verbose, render_egoposes, render_egoposes_range, render_legend)
#     159     max_patch = center_patch + diff_patch / 2
#     160 my_patch = (min_patch[0], min_patch[1], max_patch[0], max_patch[1])
# --> 161 fig, ax = explorer.render_map_patch(my_patch, explorer.map_api.non_geometric_layers, figsize=(10, 10),
#     162                                 render_egoposes_range=render_egoposes_range,
#     163                                 render_legend=render_legend)
#     165 # Plot in the same axis as the map.
#     166 # Make sure these are plotted "on top".
#     167 if render_egoposes:
#
# File ~/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1025, in NuScenesMapExplorer.render_map_patch(self, box_coords, layer_names, alpha, figsize, render_egoposes_range, render_legend, bitmap)
#    1022     bitmap.render(self.map_api.canvas_edge, ax)
#    1024 for layer_name in layer_names:
# -> 1025     self._render_layer(ax, layer_name, alpha)
#    1027 x_margin = np.minimum(local_width / 4, 50)
#    1028 y_margin = np.minimum(local_height / 4, 10)
#
# File ~/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1691, in NuScenesMapExplorer._render_layer(self, ax, layer_name, alpha, tokens)
#    1683 """
#    1684 Wrapper method that renders individual layers on an axis.
#    1685 :param ax: The matplotlib axes where the layer will get rendered.
#    (...)
#    1688 :param tokens: Optional list of tokens to render. None means all tokens are rendered.
#    1689 """
#    1690 if layer_name in self.map_api.non_geometric_polygon_layers:
# -> 1691     self._render_polygon_layer(ax, layer_name, alpha, tokens)
#    1692 elif layer_name in self.map_api.non_geometric_line_layers:
#    1693     self._render_line_layer(ax, layer_name, alpha, tokens)
#
# File ~/.local/lib/python3.8/site-packages/nuscenes/map_expansion/map_api.py:1734, in NuScenesMapExplorer._render_polygon_layer(self, ax, layer_name, alpha, tokens)
#    1731 else:
#    1732     label = None
# -> 1734 ax.add_patch(descartes.PolygonPatch(polygon, fc=self.color_map[layer_name], alpha=alpha,
#    1735                                     label=label))
#
# File ~/.local/lib/python3.8/site-packages/descartes/patch.py:87, in PolygonPatch(polygon, **kwargs)
#      73 def PolygonPatch(polygon, **kwargs):
#      74     """Constructs a matplotlib patch from a geometric object
#      75
#      76     The `polygon` may be a Shapely or GeoJSON-like object with or without holes.
#    (...)
#      85
#      86     """
# ---> 87     return PathPatch(PolygonPath(polygon), **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/patches.py:923, in PathPatch.__init__(self, path, **kwargs)
#     914 @docstring.dedent_interpd
#     915 def __init__(self, path, **kwargs):
#     916     """
#     917     *path* is a `~.path.Path` object.
#     918
#    (...)
#     921     %(Patch:kwdoc)s
#     922     """
# --> 923     super().__init__(**kwargs)
#     924     self._path = path
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/patches.py:89, in Patch.__init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      86 if antialiased is None:
#      87     antialiased = mpl.rcParams['patch.antialiased']
# ---> 89 self._hatch_color = colors.to_rgba(mpl.rcParams['hatch.color'])
#      90 self._fill = True  # needed for set_facecolor call
#      91 if color is not None:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/colors.py:177, in to_rgba(c, alpha)
#     153 """
#     154 Convert *c* to an RGBA color.
#     155
#    (...)
#     174     alpha) can assume values between 0 and 1.
#     175 """
#     176 # Special-case nth color syntax because it should not be cached.
# --> 177 if _is_nth_color(c):
#     178     from matplotlib import rcParams
#     179     prop_cycler = rcParams['axes.prop_cycle']
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/colors.py:108, in _is_nth_color(c)
#     106 def _is_nth_color(c):
#     107     """Return whether *c* can be interpreted as an item in the color cycle."""
# --> 108     return isinstance(c, str) and re.match(r"\AC[0-9]+\Z", c)
#
# File /usr/lib/python3.8/re.py:191, in match(pattern, string, flags)
#     188 def match(pattern, string, flags=0):
#     189     """Try to apply the pattern at the start of the string, returning
#     190     a Match object, or None if no match was found."""
# --> 191     return _compile(pattern, flags).match(string)
#
# KeyboardInterrupt:

# %%
random_agent.test_scene_trajectory(example_scene_df, max_steps=20, render=True, verbose = True)
#diff_aer, diff_std, transferred_learning = random_agent.compare()
# Out:
# ---------------------------------
# * START TESTING
#
# Actual state: [1294.687240740777, 792.3926376383857, 5.813254030953955, -0.0799596719840816, 1.183060465301501, -2.28299957461015, -0.4432416544945889]
# Action: Action.TURN_LEFT
# Actual state: (1292.7877511304896, 790.1925422251115, 5.813254030953955, -0.0799596719840816, 0, -2.3229794106021906, -0.1932416544945889)
# Action: Action.GAS
# Actual state: (1290.8018433545801, 788.0701259340218, 5.813754030953954, -0.0799596719840816, 0.001, -2.3629592465942313, 0.0)
# Action: Action.BRAKE
# Actual state: (1288.732513271512, 786.0286051796776, 5.813254030953955, -0.0799596719840816, -0.001, -2.402939082586272, 0.0)
# Action: Action.TURN_LEFT
# Actual state: (1286.5834236841972, 784.0715935412871, 5.813254030953955, -0.0799596719840816, 0, -2.4429189185783127, 0.25)
# Action: Action.BRAKE_TURN_LEFT
# Actual state: (1284.3578312440914, 782.2020430879311, 5.812754030953955, -0.0799596719840816, -0.001, -2.4828987545703534, 0.5)
# Action: Action.BRAKE_TURN_RIGHT
# Actual state: (1282.0594905341306, 780.4230947084018, 5.812254030953955, -0.0799596719840816, -0.001, -2.522878590562394, 0.25)
# Action: Action.BRAKE_TURN_RIGHT
# Actual state: (1279.6920869358462, 778.7375756687838, 5.8117540309539555, -0.0799596719840816, -0.001, -2.5628584265544347, 0.0)
# Action: Action.GAS_TURN_LEFT
# Actual state: (1277.2594155638742, 777.1481634424983, 5.812254030953955, -0.0799596719840816, 0.001, -2.6028382625464754, 0.25)
# Action: Action.BRAKE_TURN_LEFT
# Actual state: (1274.7649460079635, 775.6571249236397, 5.8117540309539555, -0.0799596719840816, -0.001, -2.642818098538516, 0.5)
# Action: Action.GAS_TURN_LEFT
# Actual state: (1272.213093696751, 774.2670993804079, 5.812254030953955, -0.0799596719840816, 0.001, -2.682797934530557, 0.75)
# Action: Action.BRAKE_TURN_LEFT
# Actual state: (1273.3283154218657, 769.7495088517684, 5.8117540309539555, -0.0799596719840816, -0.001, -2.7227777705225975, 1.0)
# Action: Action.TURN_LEFT
# Actual state: (1270.673588873652, 768.5677524541603, 5.8117540309539555, -0.0799596719840816, 0, -2.762757606514638, 1.25)
# Action: Action.TURN_LEFT
# Actual state: (1267.9737498418178, 767.4930476429395, 5.8117540309539555, -0.0799596719840816, 0, -2.802737442506679, 1.5)
# Action: Action.GAS
# Actual state: (1265.2331131399708, 766.527111983816, 5.812254030953955, -0.0799596719840816, 0.001, -2.8427172784987196, 0.0)
# Action: Action.GAS
# Actual state: (1266.8190457714418, 762.1644603201256, 5.812754030953955, -0.0799596719840816, 0.001, -2.8826971144907603, 0.0)
# Action: Action.BRAKE_TURN_RIGHT
# Actual state: (1264.0095286408691, 761.4203898603495, 5.812254030953955, -0.0799596719840816, -0.001, -2.922676950482801, -0.25)
# Action: Action.BRAKE
# Actual state: (1261.1727607020134, 760.7892623841882, 5.8117540309539555, -0.0799596719840816, -0.001, -2.9626567864748417, 0.0)
# Action: Action.BRAKE
# Actual state: (1262.2625570161451, 756.8549263479757, 5.811254030953956, -0.0799596719840816, -0.001, -3.0026366224668823, 0.0)
# Action: Action.BRAKE_TURN_RIGHT
# Actual state: (1259.3849369464813, 756.4524700301761, 5.810754030953956, -0.0799596719840816, -0.001, -3.042616458458923, -0.25)
# Action: Action.GAS_TURN_LEFT
# [0.         0.29200119 0.97255955 1.75155083 2.52900187 3.09706558
#  3.74978318 4.49704061 5.3541891  6.22987088 7.10690356 5.44948915
#  8.69119256 9.31811355 9.66881161 8.65767783 8.78716713 9.52363219
#  9.10340404 9.12379312]
# ADE: 5.695162375430534
# FDE: 9.1237931177576
# * END TESTING
# ---------------------------------
# * RESULTS
# * PG agent path
# Creating plot...
# /home/saramontese/.local/lib/python3.8/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
# /home/saramontese/.local/lib/python3.8/site-packages/descartes/patch.py:64: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   [asarray(r)[:, :2] for r in t.interiors])
# * True agent path
#                 x           y  velocity  yaw_rate  acceleration       yaw  \
# 3005  1294.687241  792.392638  5.813254 -0.079960      1.183060 -2.283000
# 3006  1292.563691  790.005294  6.391863 -0.048951      1.157507 -2.307469
# 3007  1290.118685  787.377907  7.171915 -0.031030      1.558763 -2.322997
# 3008  1287.574552  784.714430  7.368670 -0.015665      0.393620 -2.330828
# 3009  1285.049244  782.061085  7.327732 -0.001177     -0.081894 -2.331416
# 3010  1282.676459  779.601120  6.844771  0.002000     -0.967211 -2.330417
# 3011  1280.304536  777.109334  6.882104  0.024477      0.074684 -2.318182
# 3012  1277.971440  774.582729  6.872398  0.037720     -0.019396 -2.299306
# 3013  1275.698458  772.026567  6.842816  0.039274     -0.059177 -2.279674
# 3014  1273.577349  769.541497  6.536097  0.040041     -0.613594 -2.259659
# 3015  1271.641609  767.183210  6.103344  0.024356     -0.865698 -2.247483
# 3016  1270.143953  765.327205  5.965506  0.014358     -0.344784 -2.241743
# 3017  1266.464616  760.963716  5.488021 -0.041495     -0.885946 -2.283015
# 3018  1264.553078  758.825508  4.780452 -0.026961     -1.179360 -2.299191
# 3019  1262.989556  757.122200  4.625277 -0.016939     -0.310419 -2.307658
# 3020  1261.404970  755.408488  4.669295  0.001282      0.088059 -2.307017
# 3021  1259.837565  753.686761  4.647683  0.018838     -0.043142 -2.297580
# 3022  1258.125237  751.766393  5.146895  0.022409      0.998633 -2.286378
# 3023  1256.444345  749.853471  5.083202  0.020721     -0.127142 -2.275997
# 3024  1255.164210  748.363647  4.913086  0.026824     -0.425500 -2.265273
#
#       steering_angle
# 3005       -0.443242
# 3006       -0.242529
# 3007       -0.158753
# 3008       -0.052288
# 3009       -0.029599
# 3010        0.076866
# 3011        0.232201
# 3012        0.251399
# 3013        0.254890
# 3014        0.186822
# 3015        0.106537
# 3016       -0.116865
# 3017       -0.232057
# 3018       -0.143045
# 3019        0.007053
# 3020        0.181586
# 3021        0.246163
# 3022        0.246163
# 3023        0.246163
# 3024        0.263617
# Creating plot...
# /home/saramontese/.local/lib/python3.8/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
# /home/saramontese/.local/lib/python3.8/site-packages/descartes/patch.py:64: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   [asarray(r)[:, :2] for r in t.interiors])
